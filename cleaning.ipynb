# %%
def clean_countries(thesis_dataset):
    thesis_dataset['country2'] = thesis_dataset['country2'].replace('U.S.A.', 'United States')
    thesis_dataset['country2'] = thesis_dataset['country2'].replace('The Netherlands', 'Netherlands')
    thesis_dataset['country2'] = thesis_dataset['country2'].replace('MÃ©xico', 'Mexico')
    thesis_dataset['country2'] = thesis_dataset['country2'].replace('U.K.', 'United Kingdom')
    thesis_dataset['country2'] = thesis_dataset['country2'].replace('UK', 'United Kingdom')
    thesis_dataset['country2'] = thesis_dataset['country2'].replace('USA', 'United States')
    thesis_dataset['country2'] = thesis_dataset['country2'].replace('CA 92093 USA', 'United States')
    thesis_dataset['country2'] = thesis_dataset['country2'].replace('MA 01854 USA', 'United States')
    thesis_dataset['country2'] = thesis_dataset['country2'].replace('CB10 1SD UK', 'United Kingdom')
    thesis_dataset['country2'] = thesis_dataset['country2'].replace('PA USA', 'United States')
    thesis_dataset['country2'] = thesis_dataset['country2'].replace('Utah USA', 'United States')
    thesis_dataset['country2'] = thesis_dataset['country2'].replace('Herrenh&#228;userstr. 2 D-30419 Hannover Germany', 'Germany')
    thesis_dataset['country2'] = thesis_dataset['country2'].replace('the Netherlands', 'Netherlands')
    thesis_dataset['country2'] = thesis_dataset['country2'].replace('Czech Republic', 'Czechia')
    thesis_dataset['country2'] = thesis_dataset['country2'].replace('Czechoslovakia', 'Czechia')
    thesis_dataset['country2'] = thesis_dataset['country2'].replace('Belgium foederatum', 'Belgium')
    thesis_dataset['country2'] = thesis_dataset['country2'].replace('Singapore 138671', 'Singapore')
    thesis_dataset['country2'] = thesis_dataset['country2'].replace('North Cyprus', 'Cyprus')
    thesis_dataset['country2'] = thesis_dataset['country2'].replace('PR China', 'China')
    thesis_dataset['country2'] = thesis_dataset['country2'].replace('Cambridge', 'United Kingdom')
    thesis_dataset['country2'] = thesis_dataset['country2'].replace('Republic of Korea', 'South Korea')
    thesis_dataset['country2'] = thesis_dataset['country2'].replace('Brasil', 'Brazil')
    thesis_dataset['country2'] = thesis_dataset['country2'].replace('PA 15232 USA', 'United States')
    thesis_dataset['country1'] = thesis_dataset['country1'].replace('U.S.A.', 'United States')
    thesis_dataset['country1'] = thesis_dataset['country1'].replace('The Netherlands', 'Netherlands')
    thesis_dataset['country1'] = thesis_dataset['country1'].replace('MÃ©xico', 'Mexico')
    thesis_dataset['country1'] = thesis_dataset['country1'].replace('U.K.', 'United Kingdom')
    thesis_dataset['country1'] = thesis_dataset['country1'].replace('UK', 'United Kingdom')
    thesis_dataset['country1'] = thesis_dataset['country1'].replace('USA', 'United States')
    thesis_dataset['country1'] = thesis_dataset['country1'].replace('CA 92093 USA', 'United States')
    thesis_dataset['country1'] = thesis_dataset['country1'].replace('MA 01854 USA', 'United States')
    thesis_dataset['country1'] = thesis_dataset['country1'].replace('CB10 1SD UK', 'United Kingdom')
    thesis_dataset['country1'] = thesis_dataset['country1'].replace('PA USA', 'United States')
    thesis_dataset['country1'] = thesis_dataset['country1'].replace('Utah USA', 'United States')
    thesis_dataset['country1'] = thesis_dataset['country1'].replace('Herrenh&#228;userstr. 2 D-30419 Hannover Germany', 'Germany')
    thesis_dataset['country1'] = thesis_dataset['country1'].replace('the Netherlands', 'Netherlands')
    thesis_dataset['country1'] = thesis_dataset['country1'].replace('Czech Republic', 'Czechia')
    thesis_dataset['country1'] = thesis_dataset['country1'].replace('Czechoslovakia', 'Czechia')
    thesis_dataset['country1'] = thesis_dataset['country1'].replace('Belgium foederatum', 'Belgium')
    thesis_dataset['country1'] = thesis_dataset['country1'].replace('Singapore 138671', 'Singapore')
    thesis_dataset['country1'] = thesis_dataset['country1'].replace('North Cyprus', 'Cyprus')
    thesis_dataset['country1'] = thesis_dataset['country1'].replace('PR China', 'China')
    thesis_dataset['country1'] = thesis_dataset['country1'].replace('Cambridge', 'United Kingdom')
    thesis_dataset['country1'] = thesis_dataset['country1'].replace('Republic of Korea', 'South Korea')
    thesis_dataset['country2'] = thesis_dataset['country2'].replace('P.R.C', 'China')
    thesis_dataset['country1'] = thesis_dataset['country1'].replace('P.R.C', 'China')
    thesis_dataset['country2'] = thesis_dataset['country2'].replace('PA 15650 USA', 'United States')
    thesis_dataset['country1'] = thesis_dataset['country1'].replace('PA 15650 USA', 'United States')
    thesis_dataset['country2'] = thesis_dataset['country2'].replace('16 rue Rapha&#235;l Dubois 69622 Villeurbanne cede', 'France')
    thesis_dataset['country1'] = thesis_dataset['country1'].replace('16 rue Rapha&#235;l Dubois 69622 Villeurbanne cede', 'France')
    thesis_dataset['country2'] = thesis_dataset['country2'].replace('ROC', 'Taiwan')
    thesis_dataset['country1'] = thesis_dataset['country1'].replace('ROC', 'Taiwan') 
    return thesis_dataset

# %%
def clean_degrees(thesis_dataset):
    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph. D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph. D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.D., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.D. Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D. Ph.D.', 'PhD')
    
    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph. D', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph. D', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.S., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.S., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MSc, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MSc, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Phd', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Phd', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('B.Sc, Ph.D, M.Phil.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('B.Sc, Ph.D, M.Phil.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph D', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph D', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc, MSc, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc, MSc, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., D.Sc.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., D.Sc.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MS, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MS, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('D.V.M./PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('D.V.M./PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD/PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD/PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.D./Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D./Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('B.A.,Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('B.A.,Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, Dr.rer.nat.habil.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, Dr.rer.nat.habil.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., M.S., B.S.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., M.S., B.S.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D./M.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D./M.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. (Techn. Univ. of Denmark, 2014)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. (Techn. Univ. of Denmark, 2014)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., J.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., J.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., M.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., M.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc(Optom), PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc(Optom), PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('B.Sc. M.Sc. Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('B.Sc. M.Sc. Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MS, Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MS, Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.S. (Biochemistry), Ph.D. (Neuroscience)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.S. (Biochemistry), Ph.D. (Neuroscience)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc, BSc(Optom), PGCertOcTher, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc, BSc(Optom), PGCertOcTher, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PH.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PH.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('B.Sc., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('B.Sc., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BA, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BA, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc, PhD, ClinPsyD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc, PhD, ClinPsyD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD, Nagoya University, 1969, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, Nagoya University, 1969, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, DSc', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, DSc', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD/MD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD/MD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.D., Ph.D', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D., Ph.D', 'PhD')
    
    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. ', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD (Cantab)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD (Cantab)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PHD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PHD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD MCOptom', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD MCOptom', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, MD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, MD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('B.S., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('B.S., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('III, PhD (1925-2017)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('III, PhD (1925-2017)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.Sc., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.Sc., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Phd', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Phd', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Phd', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Phd', 'PhD')
    
    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Pd.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Pd.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph. D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph. D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, Nottingham, FRCPath', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, Nottingham, FRCPath', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('O.D., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('O.D., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.D. Ph.D', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D. Ph.D', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc MSc PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc MSc PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD (Dr rer nat)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD (Dr rer nat)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D, M.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D, M.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('B.A., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('B.A., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, MSCS', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, MSCS', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. M.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. M.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. (Technical University of Denmark)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. (Technical University of Denmark)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., M.A., M.Eng., B.A.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., M.A., M.Eng., B.A.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BA, MA, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BA, MA, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. (ANU)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. (ANU)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD ', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, MA, BA', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, MA, BA', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. (Techn. Univ. of Denmark, 2011)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. (Techn. Univ. of Denmark, 2011)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. (Techn. Univ. of Denmark, 2012)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. (Techn. Univ. of Denmark, 2012)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D M.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D M.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PT, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PT, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.D., PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D., PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.D./MSc/PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D./MSc/PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PH.D', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PH.D', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BS, MS, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BS, MS, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('D.V.M., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('D.V.M., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BA(Hons), PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BA(Hons), PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD Neurosciences', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD Neurosciences', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, Professeur', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, Professeur', 'PhD')
    
    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph. D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph. D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Jr., Ph.D', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Jr., Ph.D', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD MSc BSc MRSC', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD MSc BSc MRSC', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., M.Sc., Dipl.-Chem.,', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., M.Sc., Dipl.-Chem.,', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD MChem', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD MChem', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph. D. Psychology and Language Science', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph. D. Psychology and Language Science', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, MSc', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, MSc', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('B.S., M.S., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('B.S., M.S., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, FRSC, CChem', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, FRSC, CChem', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD/MS', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD/MS', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('"M.D.", "Ph.D."', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('"M.D.", "Ph.D."', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, University of Pennsylvania1940, PhD, University of Cambridge1942', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, University of Pennsylvania1940, PhD, University of Cambridge1942', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. (Techn. Univ. of Denmark, 2010)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. (Techn. Univ. of Denmark, 2010)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. (Fudan Univ., 2010 )', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. (Fudan Univ., 2010 )', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD  PhD  2005  University of Illinois', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD  PhD  2005  University of Illinois', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PT, DPT, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PT, DPT, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('AA, BA, PhD, HonD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('AA, BA, PhD, HonD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('B.Sc., M.Sc., PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('B.Sc., M.Sc., PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BEng, Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BEng, Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MBBS, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MBBS, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. (Techn. Univ. of Denmark, 2013)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. (Techn. Univ. of Denmark, 2013)', 'PhD')
    
    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., ABPP', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., ABPP', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., M.S.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., M.S.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc (Hons) PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc (Hons) PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc, BA, PhD, DSc, FRCSed', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc, BA, PhD, DSc, FRCSed', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.D, Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D, Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc (Hons) PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc (Hons) PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc, BA, PhD, DSc, FRCSed', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc, BA, PhD, DSc, FRCSed', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.D, Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D, Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('B. Env. Sc (Hons), PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('B. Env. Sc (Hons), PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc, Ph.D', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc, Ph.D', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.Sc. Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.Sc. Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D (University College London)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D (University College London)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('D.I.C. Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('D.I.C. Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.d ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.d ', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. Cornell, 1950, B.S. Texas Western College 1947', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. Cornell, 1950, B.S. Texas Western College 1947', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. in Experimental Psychology, Centre for Neural Science, New York University, USA', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. in Experimental Psychology, Centre for Neural Science, New York University, USA', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc PhD FRS FRSE FMedSci', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc PhD FRS FRSE FMedSci', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D/M.A./H.B.Sc.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D/M.A./H.B.Sc.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph,D,', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph,D,', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc (Hons), PhD ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc (Hons), PhD ', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D..', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D..', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, Case Western Reserve University', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, Case Western Reserve University', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('B.A., M.A., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('B.A., M.A., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.D. PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D. PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MPhil, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MPhil, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D.;', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D.;', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('ph.D', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('ph.D', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, Habil', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, Habil', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Eng., M.S., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Eng., M.S., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PT PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PT PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, Harvard University 1990', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, Harvard University 1990', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MA, BS, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MA, BS, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD, Duke University 1995, PhD, Rockefeller University 1994', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, Duke University 1995, PhD, Rockefeller University 1994', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc (Hons), PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc (Hons), PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc, PhD, DSc', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc, PhD, DSc', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD, Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc, PhD, DSc', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc, PhD, DSc', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D.; Prof.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D.; Prof.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, HdR', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, HdR', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., DSc.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., DSc.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D, MPH', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D, MPH', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. Chemistry', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. Chemistry', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('B.A., M.S., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('B.A., M.S., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD/HDR', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD/HDR', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BA (hons), PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BA (hons), PhD', 'PhD')

    
    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.d ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.d ', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD Ecology', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD Ecology', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. (Universidad AutÃ³noma de Madrid, 2010)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. (Universidad AutÃ³noma de Madrid, 2010)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.D.; Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D.; Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MPharmacol., PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MPharmacol., PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, Docent', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, Docent', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., MSc, BEng', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., MSc, BEng', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, FMedSci, FRSB', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, FMedSci, FRSB', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. Cornell University', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. Cornell University', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D.,', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D.,', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD CSci FRSC', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD CSci FRSC', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, PEng, FRSC', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, PEng, FRSC', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BAS, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BAS, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, MSc, BSc', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, MSc, BSc', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BTech(BiomedSci), PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BTech(BiomedSci), PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD and PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD and PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, MPhil', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, MPhil', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M. D., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M. D., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD Philosophy, MA Psychology', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD Philosophy, MA Psychology', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, University of Coimbra', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, University of Coimbra', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.A., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.A., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PH. D', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PH. D', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MS PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MS PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('CO/M.Sc./Ph.D', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('CO/M.Sc./Ph.D', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('VMD, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('VMD, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD (1933-2001)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD (1933-2001)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc BA MSc MSc PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc BA MSc MSc PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc, MRes, MSc, Phd', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc, MRes, MSc, Phd', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, MA, MPhil, BA', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, MA, MPhil, BA', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.D./M.Sc/PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D./M.Sc/PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D>', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D>', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D./M.S./B.S.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D./M.S./B.S.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Jr., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Jr., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.A.,Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.A.,Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., MB BChir', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., MB BChir', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD, Ph.D', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, Ph.D', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Phd', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Phd', 'PhD')
    
    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.d ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.d ', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc, Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc, Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.d', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.d', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.V.Sc., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.V.Sc., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. Mit', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. Mit', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD/MS/BA', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD/MS/BA', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. Harvard University', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. Harvard University', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BMBCh, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BMBCh, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc, MRes, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc, MRes, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., D.P.M., M.B.,B.S.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., D.P.M., M.B.,B.S.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD, Taipei Medical College 1988, PhD, University of Pennsylvania 1994', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, Taipei Medical College 1988, PhD, University of Pennsylvania 1994', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. M.D. M.B.A.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. M.D. M.B.A.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., D.Phil.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., D.Phil.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc (Hon) PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc (Hon) PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD, 1991, Harvard University, PhD, 1991, Harvard University', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, 1991, Harvard University, PhD, 1991, Harvard University', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph,D, M.Sc, B.Sc', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph,D, M.Sc, B.Sc', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc(Psychology),BMedSci(Hon1),PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc(Psychology),BMedSci(Hon1),PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, MD.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, MD.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MB, BS, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MB, BS, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD, Duke University, PhD, Duke University', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, Duke University, PhD, Duke University', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD,MSc,BSc', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD,MSc,BSc', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., Chemical Physics', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., Chemical Physics', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc. MSc. PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc. MSc. PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MSci PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MSci PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D, M.A., B.A.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D, M.A., B.A.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc(Hons) MS PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc(Hons) MS PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. (Chinese Academy of Scienses, 2013)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. (Chinese Academy of Scienses, 2013)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BA, MA PhD ScD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BA, MA PhD ScD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. (KTH Stockholm + ZJU)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. (KTH Stockholm + ZJU)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. (2013)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. (2013)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.D.Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D.Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc; PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc; PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.B.B.S, Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.B.B.S, Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD from University of Munich', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD from University of Munich', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MSci, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MSci, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc, MSc, Ph.D', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc, MSc, Ph.D', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.Sc. / Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.Sc. / Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD (Stonybrook ITP)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD (Stonybrook ITP)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., M.Sc., B.Sc.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., M.Sc., B.Sc.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MEng, MSc, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MEng, MSc, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. BSc BA', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. BSc BA', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MBA., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MBA., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. University Of Rochester', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. University Of Rochester', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhDÂ©', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhDÂ©', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSEE, MS, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSEE, MS, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. University Of Calgary/university Of Konstanz', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. University Of Calgary/university Of Konstanz', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, MS, AB', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, MS, AB', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D in Physics, UW Madison', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D in Physics, UW Madison', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., M.A.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., M.A.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. (Karlsruhe Institute of Technology, 2011)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. (Karlsruhe Institute of Technology, 2011)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD, PhD, DSc, GCVO, FRS, FRCP, FRCS', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, PhD, DSc, GCVO, FRS, FRCP, FRCS', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD. PhD.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD. PhD.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., MA, BA', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., MA, BA', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, MS, BS/BA', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, MS, BS/BA', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D.|D.T', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D.|D.T', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, University of Chile 1975', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, University of Chile 1975', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, FRS, DSc', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, FRS, DSc', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.S., Ph.D', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.S., Ph.D', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('P.h.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('P.h.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D, B.E.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D, B.E.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.D., Ph.D Biomedical Engineering', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D., Ph.D Biomedical Engineering', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD. MA', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD. MA', 'PhD')
    
    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('DC, PHD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('DC, PHD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Pd.D ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Pd.D ', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, PharmD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, PharmD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.A. Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.A. Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Pharm.D., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Pharm.D., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Diplom, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Diplom, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('B.Arch, M.Arch, Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('B.Arch, M.Arch, Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.Sc, Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.Sc, Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('B.Sc. Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('B.Sc. Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., CFY-SLP', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., CFY-SLP', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MSc/PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MSc/PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, DSc, FRAS', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, DSc, FRAS', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('DC, PHD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('DC, PHD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD, MSc, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, MSc, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc MSc PhD Phd', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc MSc PhD Phd', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('DVM, MS, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('DVM, MS, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., MA', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., MA', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D./MBA/BE', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D./MBA/BE', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('DVM PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('DVM PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.S. Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.S. Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BS, MS, PHD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BS, MS, PHD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D B.Sc', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D B.Sc', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.D.,Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D.,Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, MS', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, MS', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., Ed.D', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., Ed.D', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MSc PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MSc PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MChem, Ph. D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MChem, Ph. D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD MSc BSc', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD MSc BSc', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, MS', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, MS', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('B.Pharm., M.Sc., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('B.Pharm., M.Sc., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.D.,Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D.,Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., Ed.D', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., Ed.D', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD MSc BSc', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD MSc BSc', 'PhD')
    
    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. Linguistics', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. Linguistics', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, Harvard University 1942', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, Harvard University 1942', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('DPhil/Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('DPhil/Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, Tufts University', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, Tufts University', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD, PhD (neurophysiology), MS (Systems Eng)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, PhD (neurophysiology), MS (Systems Eng)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D./MBA', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D./MBA', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. in Psychology', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. in Psychology', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MSc. PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MSc. PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BS MS PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BS MS PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.B.B.S., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.B.B.S., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MSEd, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MSEd, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, Harvard University', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, Harvard University', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D; Prof.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D; Prof.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('CivilingenjÃ¶r, DEA, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('CivilingenjÃ¶r, DEA, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. Hispanic Linguistics', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. Hispanic Linguistics', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD, PhD, Case Western Reserve University', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, PhD, Case Western Reserve University', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, University of Coimbra, 2012', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, University of Coimbra, 2012', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D, M.D', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D, M.D', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, Rochester University', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, Rochester University', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD MD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD MD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('B.Sc. M.A. Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('B.Sc. M.A. Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('P.T., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('P.T., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD. Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD. Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD Neuroscience', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD Neuroscience', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D.Lond; D.Sc, Glas.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D.Lond; D.Sc, Glas.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., M.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., M.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MSc; PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MSc; PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, PGDipClinPsych', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, PGDipClinPsych', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. (Techn. Univ. of Denmark, 1989)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. (Techn. Univ. of Denmark, 1989)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, Albany Medical College 1987', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, Albany Medical College 1987', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Th.D., Ph.D., Th.D.habil.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Th.D., Ph.D., Th.D.habil.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. University Of Utrecht', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. University Of Utrecht', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.Sc. M.Eng. Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.Sc. M.Eng. Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD, Medical School of Gdansk, PhD, Warsaw Medical School', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, Medical School of Gdansk, PhD, Warsaw Medical School', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. California Institute Of Technology', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. California Institute Of Technology', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD PhD,1990  Universite Catholique, Louvain, Belgium', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD PhD,1990  Universite Catholique, Louvain, Belgium', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., M.A., B.A.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., M.A., B.A.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc (Special), MSc, Ph.D', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc (Special), MSc, Ph.D', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. University Of Chicago', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. University Of Chicago', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD PhD, Jefferson University', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD PhD, Jefferson University', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD DABT', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD DABT', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D./M.Sc.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D./M.Sc.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. Rutgers University', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. Rutgers University', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MChem PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MChem PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.Sc., PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.Sc., PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD, Seoul University, PhD, Seoul University', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, Seoul University, PhD, Seoul University', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. (Univ. Salento)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. (Univ. Salento)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc (University of Leeds), PhD (University of Windsor)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc (University of Leeds), PhD (University of Windsor)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D, B.Eng', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D, B.Eng', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D.(Edu', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D.(Edu', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MS, DVM, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MS, DVM, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD, Universidad de Buenos Aires Escuela de Medicina, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, Universidad de Buenos Aires Escuela de Medicina, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, Technicon-Israel Institute of Technology 2002', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, Technicon-Israel Institute of Technology 2002', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD, Morehouse University, PhD, Morehouse University', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, Morehouse University, PhD, Morehouse University', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD,PhD, Case Western Reserve University', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD,PhD, Case Western Reserve University', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PD Ph.D', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PD Ph.D', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. University Of Heidelberg', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. University Of Heidelberg', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, Yale University', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, Yale University', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('C., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('C., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.A., PhD, FRHistS, FSA, FLSW, FBA', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.A., PhD, FRHistS, FSA, FLSW, FBA', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MPH, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MPH, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.Div., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.Div., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D.|D.P', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D.|D.P', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD, Tapei University, PhD, University of Minnesota', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, Tapei University, PhD, University of Minnesota', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.Sc., Ph.D., M.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.Sc., Ph.D., M.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. Eng.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. Eng.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D, M.Sc. B.Sc', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D, M.Sc. B.Sc', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD, University of Vienna, PhD, University of Vienna', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, University of Vienna, PhD, University of Vienna', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., M.Div., M.A.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., M.Div., M.A.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, FBA, Sir', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, FBA, Sir', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, BPharm', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, BPharm', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc, MSc, PHD, PCAP, FHEA', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc, MSc, PHD, PCAP, FHEA', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. Stony Brook', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. Stony Brook', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MRes, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MRes, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., LL.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., LL.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, FRS, FMedSci', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, FRS, FMedSci', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MA cantab, PhD london, ScD Cambridge', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MA cantab, PhD london, ScD Cambridge', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('phD, MD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('phD, MD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D,', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D,', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, DPhil', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, DPhil', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc, BA (hons), PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc, BA (hons), PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D, M.S., M.Eng', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D, M.S., M.Eng', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.D., M.P.H., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D., M.P.H., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D / MBA', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D / MBA', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D:', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D:', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('D.C., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('D.C., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MS., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MS., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., M.Sc.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., M.Sc.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Phd, MD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Phd, MD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, FBPsS', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, FBPsS', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BA, Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BA, Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD,PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD,PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('DVM, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('DVM, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., MBBS', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., MBBS', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD, PHD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, PHD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., M.S. Biomedical Engineering', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., M.S. Biomedical Engineering', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. Biomedical Engineering', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. Biomedical Engineering', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BFA, DipArts, BA (hons), PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BFA, DipArts, BA (hons), PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, University of Pennsylvania', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, University of Pennsylvania', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. Syracuse University', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. Syracuse University', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD BSc(Hons)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD BSc(Hons)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MPharm, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MPharm, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Theoretical Particle Physics, Ph.D', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Theoretical Particle Physics, Ph.D', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, Stanford University', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, Stanford University', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD,Tufts University, PhD, Tufts University 1976', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD,Tufts University, PhD, Tufts University 1976', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, M.S. B. E', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, M.S. B. E', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, MusM, BMT', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, MusM, BMT', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('(PhD in Neuroscience)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('(PhD in Neuroscience)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('phD ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('phD ', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MA, MSc, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MA, MSc, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD, University of Chicago1989, PhD, University of Chicago1987', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, University of Chicago1989, PhD, University of Chicago1987', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MSci (Hons) Dunelm, Ph.D. UCL', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MSci (Hons) Dunelm, Ph.D. UCL', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. Yale University', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. Yale University', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD., PhD.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD., PhD.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD/MSB', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD/MSB', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('B.S., M.S. Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('B.S., M.S. Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. Leningrad University', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. Leningrad University', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D/MD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D/MD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD.,PhD.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD.,PhD.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., DSc', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., DSc', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. 2005, MIT and Woods Hole Oceanographic Institute M.S. 1999, Stanford University B.S. 1998, Stanford University', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. 2005, MIT and Woods Hole Oceanographic Institute M.S. 1999, Stanford University B.S. 1998, Stanford University', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D, BS', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D, BS', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD, University of Pennsylvania, PhD, University of Pennsylvania', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, University of Pennsylvania, PhD, University of Pennsylvania', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., D.Sc., B.Ph.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., D.Sc., B.Ph.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD,  FRS', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD,  FRS', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., University of Michigan', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., University of Michigan', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. in Theoretical Physics', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. in Theoretical Physics', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD (Illinois)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD (Illinois)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD/Dr rer nat', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD/Dr rer nat', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Dipl. Ing., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Dipl. Ing., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.D, Ph.D', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D, Ph.D', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D, B.S.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D, B.S.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. D.Sc', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. D.Sc', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, BSc', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, BSc', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.Dl', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.Dl', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. (ABD)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. (ABD)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('S.M., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('S.M., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD in Biochemistry', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD in Biochemistry', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., C.Psych.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., C.Psych.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. R.P', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. R.P', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. Inorganic Chemistry, Stanford University', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. Inorganic Chemistry, Stanford University', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('D.Phil., D.Sc., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('D.Phil., D.Sc., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc PhD DAES', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc PhD DAES', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('VMD PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('VMD PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc(Hons), PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc(Hons), PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc., MSc., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc., MSc., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc, PhD, Dr.rer.nat.habil.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc, PhD, Dr.rer.nat.habil.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Au.D., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Au.D., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., Prof.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., Prof.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Pharm. D., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Pharm. D., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('A.B., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('A.B., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, University of Heidelberg 1989', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, University of Heidelberg 1989', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, DDS', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, DDS', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MBChB, MSc, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MBChB, MSc, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D, D.Sc.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D, D.Sc.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD, PhD.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, PhD.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. (Copenhagen Univ., 1993)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. (Copenhagen Univ., 1993)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('B.Sci. (Hons), B.Eng. (Hons), Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('B.Sci. (Hons), B.Eng. (Hons), Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.D. Ph. D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D. Ph. D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('B.A., M.Sc., Ph.D. (Biological Sciences)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('B.A., M.Sc., Ph.D. (Biological Sciences)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. Spanish Linguistics', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. Spanish Linguistics', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PM.D., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PM.D., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D."', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D."', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., University of Kansas', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., University of Kansas', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.A. Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.A. Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.A. Ph.D. M.B.Chir.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.A. Ph.D. M.B.Chir.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. University Of Amsterdam', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. University Of Amsterdam', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('B.S. with Honors, Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('B.S. with Honors, Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., P.T.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., P.T.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BS, MA, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BS, MA, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.B.B.S, Ph.D', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.B.B.S, Ph.D', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('ph.d. ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('ph.d. ', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.D. P.h.D', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D. P.h.D', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('phd ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('phd ', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. Genetics', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. Genetics', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D Ecology and Evolutionary Biology', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D Ecology and Evolutionary Biology', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, University of Pittsburgh, 2006', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, University of Pittsburgh, 2006', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, Linguistics', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, Linguistics', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MA PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MA PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, Imperial College', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, Imperial College', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, University of Salford 1995', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, University of Salford 1995', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, M.Sc, B.Sc.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, M.Sc, B.Sc.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D - M.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D - M.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD,Kansai Medical University 1969, PhD, Kansai Medical University 1974', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD,Kansai Medical University 1969, PhD, Kansai Medical University 1974', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD, Kyoto University 1986, PhD, Kyoto University 1993', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, Kyoto University 1986, PhD, Kyoto University 1993', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Distinguished Ph.D. Indiana University', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Distinguished Ph.D. Indiana University', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. University Of Texas At Austin', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. University Of Texas At Austin', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, University of California Berkeley, 1977', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, University of California Berkeley, 1977', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, MDiv, BA', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, MDiv, BA', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., D.Sci.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., D.Sci.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BS, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BS, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc, MS, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc, MS, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., B.Sc.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., B.Sc.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD Aeronautics', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD Aeronautics', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. (Harvard)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. (Harvard)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('D.V.M.-Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('D.V.M.-Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. (Idaho)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. (Idaho)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('DC, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('DC, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BPsych, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BPsych, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D, MHA', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D, MHA', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc,PhD, DSc', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc,PhD, DSc', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MBChB, BSc, PhD, MD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MBChB, BSc, PhD, MD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MBChB, BSc, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MBChB, BSc, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MB BChir MA PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MB BChir MA PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. Physics', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. Physics', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D Physics', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D Physics', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.D., Ph.D., M.Phil.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D., Ph.D., M.Phil.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D, MHA', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D, MHA', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BA, DipAppPsych, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BA, DipAppPsych, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Phd, DSc', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Phd, DSc', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD Genetics UCSF', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD Genetics UCSF', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, Shushi, BS', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, Shushi, BS', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., FRS', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., FRS', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD/ MD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD/ MD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., CSC', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., CSC', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph D, MD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph D, MD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph. D. Indiana University; B. A. Chemistry, B. A. Russian Language, Grinnell College', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph. D. Indiana University; B. A. Chemistry, B. A. Russian Language, Grinnell College', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. in biochemistry, Aix-Marseille University.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. in biochemistry, Aix-Marseille University.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Bsc, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Bsc, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. D.Sc.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. D.Sc.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D." ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D." ', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('ph.d. ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('ph.d. ', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc, MPhil, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc, MPhil, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc MA PhD ScD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc MA PhD ScD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('phd  ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('phd  ', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.A. Ph.D. ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.A. Ph.D. ', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.D., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. (Copenhagen Univ., 1981)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. (Copenhagen Univ., 1981)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. (Aarhus Univ., 1983)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. (Aarhus Univ., 1983)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BPharm, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BPharm, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, Physics', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, Physics', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('D.V.M.-Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('D.V.M.-Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, Imperial College ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, Imperial College ', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.S., A.M., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.S., A.M., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BOptom, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BOptom, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MbChB, BSc, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MbChB, BSc, PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. Weizmann Institute', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. Weizmann Institute', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BA PhD ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BA PhD ', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('phD  ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('phD  ', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD,University of Illinois, PhD, FCAP', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD,University of Illinois, PhD, FCAP', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MS (Case Western Reserve University), PhD (University of Amsterdam)2012', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MS (Case Western Reserve University), PhD (University of Amsterdam)2012', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., J.D., M.A.R.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., J.D., M.A.R.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D. (Techn. Univ. of Denmark, 2009)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. (Techn. Univ. of Denmark, 2009)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MA, PhD ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MA, PhD ', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MA, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MA, PhD', 'PhD')

    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PH.d.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. University Of California', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('B.Sc., B.Sc. (Hons I), PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, MBA', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, University of California San Diego, PhD, University of California San Diego', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, FPharmS, GRIC, CChem', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, University of California Berkeley 1975', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. (Cornell Univ., 1982)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, Imperial College 1979', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, LP', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., M.Sc., Dipl.-Chem.,', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. University Of Maryland', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD (Oregon State University)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. Moscow State University', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. Novosibirsk Institute Of Nuclear Physics', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, MS, BA', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, University of Iowa', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., B.A.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc(Hons), PhD, PGDipClinPsych', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph. D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. Princeton University', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, MS, MA, BA', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D./D.D.S.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD and Dr rer nat', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. (UIUC, 1957)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('ph.d. University Of Freiburg', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. University Of Florida', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. Cambridge', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MBChB, PhD, DSc', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D. and Ph. D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD DSc', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. Linguistics and Cognitive Science', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. (1993)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., Sc.D', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('phd ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. (Molecular Biology, TIFR, 1993)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. Vanderbilt University', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., BCBA-D', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('J.D., Ph.D', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. Columbia University', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Jr., PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph D University of Califronia, Berkeley', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. BCBA', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('RN, MSc, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. University of California', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, University of Kentucky', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc, PGTC, PhD, DSc', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('D.V.M.-Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. (Poznan)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD Ohio State', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., CCC-SLP', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., M.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, Dr. Med, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, Stanford University 2005', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D./M.S./B.A.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PD PhD MSc BSc', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.A., Ph.D., Sc.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, D.Phil', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MDS, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, MSPH', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. and Prof.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D, MS, BS', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, ScD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc, Phd, DSc', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D, UCSD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, University of California Berkeley', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('CM, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc, PhD.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, HonFBPhS', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MBBS,BSc(Med),PhD,FRACP,FRCPA', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, PT', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D.; MSc Pharm', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Jr., Ph.D. (U Washintgon)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, University of California San Diego', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., B.S.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('B.A., B.D., M.Th., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D in Physics, MPhys in Physics with Medical Physics [1st class hons]', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD Tianjin', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, V.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('ph.d ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, HDR', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Jr, Ph.D', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, University of Zagreb, PhD, University of Zagreb', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, University of Colorado 1992', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.S.,Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D., Ph.D., FRCSC', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, RN.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('B. Scc, Ph. D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, BCBA', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BA, PhD (Wales), FRHistS', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D, Downstate Medical Center', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, University of Michigan', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BA PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Md, PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD., PH.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, University of California Davis', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('ph.d.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D/MBBS/HHMI', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD FRCP FRCPsych FMedSci', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. University Of Pittsburgh', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. Eotvos University', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, JD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, M.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, DSc, FRCP', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD PhD DSc', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Prof. Dr. Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, Medical College of Pennsylvania, PhD, Medical College of Pennsylvania', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace(' PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('ph.d  ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., M.D. ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D. (Molecular Biology, TIFR, 1993)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc, MSc, PhD ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., University of Minnesota', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('phd  ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('D.V.M.-Ph.D. ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, Stanford University 1991', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD FBCO', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph. D.', 'PhD')
    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('DPhil', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('DPhil', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('D.Phil.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('D.Phil.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('D.Phil ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('D.Phil ', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('D.Phil., MA', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('D.Phil., MA', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Dr. phil.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Dr. phil.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Dr.Ph.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Dr.Ph.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Dr.Ph.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Dr.Ph.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('D. Phil.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('D. Phil.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph. D. ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph. D. ', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., M.Sc., Dipl.-Chem.,', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., M.Sc., Dipl.-Chem.,', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('D.Ph.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('D.Ph.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('D Phil', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('D Phil', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('DPhil, Oxford University', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('DPhil, Oxford University', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Dr.Phil.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Dr.Phil.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.D., D.Phil.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D., D.Phil.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('D. Phil', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('D. Phil', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MA, DPhil', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MA, DPhil', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('D.phil.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('D.phil.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MB, BS, DPhil', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MB, BS, DPhil', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('B Sc, ARCS, D Phil', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('B Sc, ARCS, D Phil', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('D.Phil, J.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('D.Phil, J.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MA DPhil', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MA DPhil', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MSc, DPhil', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MSc, DPhil', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD MPhil (Cantab)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD MPhil (Cantab)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.Chem., D.Phil.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.Chem., D.Phil.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MSci (Hons), PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MSci (Hons), PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MA DPhil DSc FRSB FRSC MAE FMedSci', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MA DPhil DSc FRSB FRSC MAE FMedSci', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.A., D.Phil. (Oxon.)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.A., D.Phil. (Oxon.)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc DPhil DSc', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc DPhil DSc', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('B.Sc., B.Sc. (Hons I), PhD', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('B.Sc., B.Sc. (Hons I), PhD', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Dr. rer. nat. (Ph.D.)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Dr. rer. nat. (Ph.D.)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc (Hons), MSc, DPhil', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc (Hons), MSc, DPhil', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('B.S., M.A., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('B.S., M.A., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('BSc (Biochemistry), PhD (Physiology and Pharmacology)', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('BSc (Biochemistry), PhD (Physiology and Pharmacology)', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., M.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., M.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD DPhil', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD DPhil', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD, Kyoto University,PhD, Kyoto University', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, Kyoto University,PhD, Kyoto University', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.B., D.Phil., F.R.S.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.B., D.Phil., F.R.S.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD, University of Zagreb, PhD, University of Zagreb ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, University of Zagreb, PhD, University of Zagreb ', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD, Medical College of Wisconsin1996, PhD, Medical College of Wisconsin ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, Medical College of Wisconsin1996, PhD, Medical College of Wisconsin ', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('PhD, Duke University 1975', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('PhD, Duke University 1975', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD, MSc, DPhil', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, MSc, DPhil', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('D.Phil., M.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('D.Phil., M.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('ph.d.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('ph.d.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.D, DPhil', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D, DPhil', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('D.Phil.., M.A.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('D.Phil.., M.A.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('D.Phil. MA', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('D.Phil. MA', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('M.D., Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('M.D., Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('MD, DPhil', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('MD, DPhil', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('D.V.M.-Ph.D.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('D.V.M.-Ph.D.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('DPhil, OBE, FRSE, FIBiol', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('DPhil, OBE, FRSE, FIBiol', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('DPhil, CBE', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('DPhil, CBE', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Dr. Phil., Dr. Med.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Dr. Phil., Dr. Med.', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D., M.D. ', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D., M.D. ', 'PhD')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('D.Phil., FRS', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('D.Phil., FRS', 'PhD')
    
    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('D.Ed.', 'Ed.D.')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('D.Ed.', 'Ed.D.')

    thesis_dataset['degrees1'] = thesis_dataset['degrees1'].replace('Ph.D, DVM', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('Ph.D, DVM', 'PhD')

    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('D. Phil., D.Sc.', 'PhD')
    thesis_dataset['degrees2'] = thesis_dataset['degrees2'].replace('D. Phil., D.Sc.', 'PhD')

    return thesis_dataset
